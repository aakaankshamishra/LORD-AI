# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
merged_data=[]

# %%
df= pd.read_csv("/content/drive/MyDrive/merged/application_data.csv")
df2=pd.read_csv("/content/drive/MyDrive/merged/previous_application.csv")

# %%
#merged_data = df.merge(df2, on='SK_ID_CURR', how= 'inner')

# %%
#merged_data=pd.read_csv("/content/drive/MyDrive/merged/merged_data.csv")

# %%
#print(merged_data)

# %%
#missing_data= merged_data.isnull().sum()
#print(missing_data)
#missing_data.to_csv('/content/drive/MyDrive/merged/missing.csv', index=False)
# Out:
# SK_ID_CURR                        0
# TARGET                            0
# NAME_CONTRACT_TYPE_x              0
# CODE_GENDER                       0
# FLAG_OWN_CAR                      0
#                               ...
# DAYS_FIRST_DUE               561106
# DAYS_LAST_DUE_1ST_VERSION    561106
# DAYS_LAST_DUE                561106
# DAYS_TERMINATION             561106
# NFLAG_INSURED_ON_APPROVAL    561106
# Length: 158, dtype: int64

# %%
print(df.shape)
print(df2.shape)
# Out:
# (307511, 122)
# (1670214, 37)

# %%
missing_data1= df.isnull().sum()
print(missing_data1)
missing_data2= df2.isnull().sum()
print(missing_data2)
# Out:
# SK_ID_CURR                        0
# TARGET                            0
# NAME_CONTRACT_TYPE                0
# CODE_GENDER                       0
# FLAG_OWN_CAR                      0
#                               ...
# AMT_REQ_CREDIT_BUREAU_DAY     41519
# AMT_REQ_CREDIT_BUREAU_WEEK    41519
# AMT_REQ_CREDIT_BUREAU_MON     41519
# AMT_REQ_CREDIT_BUREAU_QRT     41519
# AMT_REQ_CREDIT_BUREAU_YEAR    41519
# Length: 122, dtype: int64
# SK_ID_PREV                           0
# SK_ID_CURR                           0
# NAME_CONTRACT_TYPE                   0
# AMT_ANNUITY                     372235
# AMT_APPLICATION                      0
# AMT_CREDIT                           1
# AMT_DOWN_PAYMENT                895844
# AMT_GOODS_PRICE                 385515
# WEEKDAY_APPR_PROCESS_START           0
# HOUR_APPR_PROCESS_START              0
# FLAG_LAST_APPL_PER_CONTRACT          0
# NFLAG_LAST_APPL_IN_DAY               0
# RATE_DOWN_PAYMENT               895844
# ...

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-5-bf934754a5b1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df2.fillna(df2.mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c3dfc87eb8e7> in <cell line: 1>()
# ----> 1 df2.fillna(df2.mean(), inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
#   11402             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403         )
#
# ...

# %%
missing_data1= df.isnull().sum()
print(missing_data1)
# Out:
# SK_ID_CURR                    0
# TARGET                        0
# NAME_CONTRACT_TYPE            0
# CODE_GENDER                   0
# FLAG_OWN_CAR                  0
#                              ..
# AMT_REQ_CREDIT_BUREAU_DAY     0
# AMT_REQ_CREDIT_BUREAU_WEEK    0
# AMT_REQ_CREDIT_BUREAU_MON     0
# AMT_REQ_CREDIT_BUREAU_QRT     0
# AMT_REQ_CREDIT_BUREAU_YEAR    0
# Length: 122, dtype: int64

# %%
missing_data2= df2.isnull().sum()
print(missing_data2)

# %%
modes = df.mode()
df.fillna(modes.iloc[0], inplace=True)

# %%
modes2 = df2.mode()
df2.fillna(modes.iloc[0], inplace=True)

# %%
missing_data1= df.isnull().sum()
print(missing_data1)
missing_data1.to_csv('/content/drive/MyDrive/merged/missing2.csv', index=False)
# Out:
# SK_ID_CURR                    0
# TARGET                        0
# NAME_CONTRACT_TYPE            0
# CODE_GENDER                   0
# FLAG_OWN_CAR                  0
#                              ..
# AMT_REQ_CREDIT_BUREAU_DAY     0
# AMT_REQ_CREDIT_BUREAU_WEEK    0
# AMT_REQ_CREDIT_BUREAU_MON     0
# AMT_REQ_CREDIT_BUREAU_QRT     0
# AMT_REQ_CREDIT_BUREAU_YEAR    0
# Length: 122, dtype: int64

# %%
missing_data2= df2.isnull().sum()
print(missing_data2)

# %%
#missing_data2= merged_data.isnull().sum()
#print(missing_data)

# %%
#missing_data2.to_csv('/content/drive/MyDrive/merged/missing2.csv', index=False)
# merged_data.to_csv('/content/drive/MyDrive/merged/merged_data.csv', index=False)

# %%
df.to_csv('/content/drive/MyDrive/merged/cleanapplication_data.csv', index=False)

# %%
df2.to_csv('/content/drive/MyDrive/merged/cleanprevious_application.cs', index=False)
